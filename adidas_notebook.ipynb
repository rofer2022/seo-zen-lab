# %% [markdown]
# <a href="https://seo-zen.com/"><img src="https://seo-zen.com/wp-content/uploads/2025/03/Group-4-1.png"></a>

# %% [markdown]
# # Analyzing Adidas Keyword Variations Across Key Southeast Asian Markets: Indonesia, Philippines, Thailand, and Vietnam

# %% [markdown]
# In an era where consumer behaviors constantly evolve, understanding keyword trends is essential for marketers aiming to stay relevant and competitive. This installment of the “Brand Search Intelligence” series provides deep insights into Adidas-related search patterns in Southeast Asia’s largest markets: Indonesia, Philippines, Thailand, and Vietnam.

# %% [markdown]
# ## Tools and Methodology
# This research was built on a three-tiered approach combining robust <a href="https://seo-zen.com/free-keyword-research-for-seo-strategy/">SEO keyword analytics</a>, dynamic visualizations, and intelligent automation:
#
# <b>Data Collection (Semrush):</b> The primary tool for capturing indexed keyword data was Semrush, renowned for its expansive keyword database. It provided comprehensive, detailed insights into country-specific keyword volumes, helping uncover trends, demands, and shifts.
#
# <b>Visualization (Jupyter Notebook with Python):</b> Data was transformed into clear, informative visualizations using Python’s pandas and plotly libraries within a Jupyter notebook environment. This facilitated efficient data interpretation, showcasing complex information in easily digestible formats like treemaps and word clouds.
#
# <b>Automated Analysis (ChatGPT):</b> To expedite data interpretation and audience segmentation, ChatGPT played a critical role. It significantly streamlined the categorization of audience types, keyword analysis, and strategic recommendations, enhancing overall efficiency.

# %% [markdown]
# ### Market Analysis: Keyword Trends and Audience Insights
# Below is an in-depth breakdown of keyword analysis per country, exploring keyword preferences, audience personas, and market-specific strategic insights:

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
adidas_kw_trends.head()
# Out:
#      Country   Keyword  Search Volume
# 0  Indonesia    sepatu         442750
# 1  Indonesia     samba         323400
# 2  Indonesia  original         250760
# 3  Indonesia     harga         164700
# 4  Indonesia   spezial          97700

# %%
##assigning dataframe for Indonesia Search trend
df_indonesia = adidas_kw_trends[adidas_kw_trends['Country'] == 'Indonesia']

##assigning dataframe for The Philippines Search trend
df_philippines = adidas_kw_trends[adidas_kw_trends['Country'] == 'Philippines']

##assigning dataframe for Thailand Search trend
df_thailand = adidas_kw_trends[adidas_kw_trends['Country'] == 'Thailand']

##assigning dataframe for Vietnam Search Trend
df_vietnam = adidas_kw_trends[adidas_kw_trends['Country'] == 'Vietnam']

# %% [markdown]
# # Visualization Chart for Each Market
# ## Indonesia, The Philippines, Thailand and Vietnam

# %% [markdown]
# [1] Indonesia

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.barplot(x='Search Volume', y='Keyword', data=df_indonesia.sort_values('Search Volume', ascending=False), palette='viridis')
plt.title('Keyword Search Volume (Indonesia)', fontsize=16)
plt.xlabel('Search Volume')
plt.ylabel('Keywords')
plt.show()

# %% [markdown]
# # Key Insights & Findings for Indonesia Market

# %% [markdown]
# <b>Most Common Keywords:</b> “sepatu” (shoes), “samba,” “original,” “harga” (price), “spezial,” “indonesia,” “shoes,” “gazelle,” “running.”
#
# <b>Audience Persona:</b> The Indonesian market primarily consists of practical consumers and price-sensitive upgraders. The keyword volume around “harga” (price) and model-specific terms indicates a consumer base seeking both affordability and product authenticity.
#
# <b>Demand & Insights:</b> There’s a substantial interest in popular product lines like “Samba,” “Gazelle,” and performance-oriented terms like “running.” Adidas Brand, Retailers and Marketers should emphasize promotional strategies focusing on affordability, product authenticity, and practical value.

# %% [markdown]
# [2] The Philippines

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.barplot(x='Search Volume', y='Keyword', data=df_philippines.sort_values('Search Volume', ascending=False), palette='viridis')
plt.title('Keyword Search Volume (Philippines)', fontsize=16)
plt.xlabel('Search Volume')
plt.ylabel('Keywords')
plt.show()

# %% [markdown]
# # Key Insights & Findings for The Philippines Market

# %% [markdown]
# <b>Most Common Keywords:</b> “shoes,” “samba,” “price,” “women,” “white,” “boost,” “black,” “men,” “size.”
#
# <b>Audience Persona:</b> Philippines market exhibit brand-conscious purchasing behavior, marked by interest in pricing and product variants. High-volume search terms such as “shoes,” “price,” and gender-specific keywords indicate both legacy consumers and aspirational upgraders.
#
# <b>Demand & Insights:</b> Marketing strategies should emphasize gender-specific product lines, sizing options, and competitive pricing. Campaigns should target clearly segmented demographics, highlighting Adidas’ brand appeal, comfort, and product diversity.

# %% [markdown]
# [4] Thailand

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.barplot(x='Search Volume', y='Keyword', data=df_thailand.sort_values('Search Volume', ascending=False), palette='viridis')
plt.title('Keyword Search Volume (Thailand)', fontsize=16)
plt.xlabel('Search Volume')
plt.ylabel('Keywords')
plt.show()

# %% [markdown]
# # Key Insights & Findings for Thailand Market

# %% [markdown]
# <b>Most Common Keywords:</b> “samba,” “shoes,” “thailand,” “boost,” “price,” “superstar,” “predator,” “ultra,” “yeezy.”
#
# <b>Audience Persona:</b> Thailand’s consumer base appears driven by trends, premium products, and fashionable selections. The recurring use of premium model names like “Superstar,” “Yeezy,” and sports technical models such as “Predator” and “Ultra Boost” indicates early adopters and premium upgraders.
#
# <b>Demand & Insights:</b> To effectively capture the Thai market, campaigns should focus on premium positioning, highlighting product innovation, style, exclusivity, and performance. Search & social marketing strategies must highlight exclusivity, popular models, and innovative technologies.

# %% [markdown]
# [4] Vietnam

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
sns.barplot(x='Search Volume', y='Keyword', data=df_vietnam.sort_values('Search Volume', ascending=False), palette='viridis')
plt.title('Keyword Search Volume (Vietnam)', fontsize=16)
plt.xlabel('Search Volume')
plt.ylabel('Keywords')
plt.show()

# %% [markdown]
# # Key Insights & Findings for Vietnam Market¶

# %% [markdown]
# <b>Most Common Keywords:</b> “shoes,” “men,” “shirt,” “sandals,” “store,” “authentic,” “samba,” “women,” “boost.”
#
# <b>Audience Persona:</b> Vietnam’s audience emerges as meticulous shoppers, detail-oriented, and authenticity-driven. Searches related to “authentic,” “store,” and specific categories like “sandals” and “shirts” show their careful consideration of product authenticity and detailed comparative analysis.
#
# <b>Demand & Insights:</b> Marketers should prioritize educational and authenticity-focused content, ensuring clear communication on product legitimacy, detailed product specifications, and benefits. Offering localized promotions and comprehensive informational content can significantly enhance market penetration.

# %% [markdown]
# # Key Takeaways

# %% [markdown]
# Distinct patterns and strategies emerge across these markets, which Adidas Brand or Retail stores should leverage:

# %% [markdown]
# ## Indonesia and The Philippines:
#
# Focus should be on affordability, authenticity, and diverse product ranges. Campaigns highlighting value, price transparency, promotions, and consumer-focused messaging will resonate deeply.

# %% [markdown]
# ## Thailand:
# Emphasis on premium positioning,
# exclusivity, and stylish innovations is critical. Online search campaigns can leverage higher CPCs strategically to capture this premium-focused market.

# %% [markdown]
# ## Vietnam:
# Authenticity, educational content, and meticulous product information will strongly influence conversions. Prioritize highly informative SEO content and targeted educational SEM campaigns.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Load the Excel file

df = adidas_kw_trends

df['Keyword'] = df['Keyword'].astype(str)
df['Search Volume'] = df['Search Volume'].astype(int)

# Check column names
print(df.head())

# Ensure the correct column names
keyword_column = "Keyword"  
volume_column = "Search Volume"  

# Aggregate keyword frequencies
word_freq = df.groupby(keyword_column)[volume_column].sum().to_dict()

# Generate Word Cloud
wordcloud = WordCloud(width=500, height=300, background_color="white", colormap="viridis").generate_from_frequencies(word_freq)

# Display Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#      Country   Keyword  Search Volume
# 0  Indonesia    sepatu         442750
# 1  Indonesia     samba         323400
# 2  Indonesia  original         250760
# 3  Indonesia     harga         164700
# 4  Indonesia   spezial          97700
